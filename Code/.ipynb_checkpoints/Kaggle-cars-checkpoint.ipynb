# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv(r'C:/Users/juan.romero/Documents/2. Personal/modelo predictivo/OLX_cars_dataset00/OLX_cars_dataset00.csv')

# %%
data.head(10)
# Out:
#         Ad ID                                         Car Name      Make  \
# 0  1079071571                     Fresh Import Passo 2021Model    Toyota
# 1  1080125520                                      Suzuki Ravi    Suzuki
# 2  1080748789            Suzuki Bolan 2015 Contact 03112271054    Suzuki
# 3  1076081635                               Diahatsu Move 2013  Daihatsu
# 4  1080812928               Suzuki Swift Dlx 2011 Miner Tuchap    Suzuki
# 5  1079496823                         Wagonr Ags Total Genuine    Suzuki
# 6  1080333426                                    Daihatsu Mira  Daihatsu
# 7  1080784758  Suzuki Bolan 2016 Genuine Condition Low Mileage    Suzuki
# 8  1076448625                                  2004 Honda City     Honda
# 9  1080820574          Car Bashir S 80 Janwan Hain 03218823600    Suzuki
#
#         Model  Year  KM's driven    Price    Fuel Registration city  \
# 0       Passo  2021        54000  4190000  Petrol      Unregistered
# ...

# %%
data["Images URL's"] = data["Images URL's"].str.replace("['","")
data["Images URL's"] = data["Images URL's"].str.replace("']","")

# %%
data["Car Name"] = data["Car Name"].str.title()
data["Description"] = data["Description"].str.title()

# %%
data["Description"] = data["Description"].astype('string')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9179 entries, 0 to 9178
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ad ID              9179 non-null   int64
#  1   Car Name           9179 non-null   object
#  2   Make               9179 non-null   object
#  3   Model              9179 non-null   object
#  4   Year               9179 non-null   int64
#  5   KM's driven        9179 non-null   int64
#  6   Price              9179 non-null   int64
#  7   Fuel               9179 non-null   object
#  8   Registration city  9179 non-null   object
#  9   Car documents      9179 non-null   object
#  10  Assembly           9179 non-null   object
#  11  Transmission       9179 non-null   object
#  12  Condition          9179 non-null   object
#  13  Seller Location    9179 non-null   object
#  14  Description        9179 non-null   string
#  15  Car Features       9179 non-null   object
# ...
